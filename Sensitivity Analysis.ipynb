# %% [markdown]
# Three sink source pairs are symmetrically arranged above and below the horizontal axis.
#
# The sources at (-8, +/- 1) are twice as strong as the sinks at (1, +/- 1) and (10, +/- 1) .
# (1, +/- 1)
# The contaminant flow capture by the downstream extraction wells is clearly visible.
#
# The plume boundary can be roughly inferred from the streamline heading up/down from the stagnation point at approximately (-13,0).
#
# The streamlines are not dramatically affected when each of the pairs is replaced with a single source or sink with combined strength of the  pair it replaces.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')
import numpy as np

# %% [markdown]
# Plot of the the streamlines

# %%
plt.figure(figsize=(20,15))
x = np.linspace(-25, 25, 250)
y = np.linspace(-25, 15, 250)
plt.xlim(-25, 25)
plt.ylim(-15,15)
X, Y = np.meshgrid(x, y)
Z = -Y-4*np.arctan2(Y-1,(X+8))+2*np.arctan2(Y-1,(X-1))-4*np.arctan2(Y+1,(X+8))+2*np.arctan2(Y+1,(X-1))+2*np.arctan2(Y-1,(X-10))+2*np.arctan2(Y+1,(X-10))
contours=plt.contour(X, Y, Z, levels=np.linspace(-25,25,30), colors='black')
plt.gca().tick_params(labelsize=25)
#plt.clabel(contours, inline=True, fontsize=15)
plt.savefig('3sspairA.png')

# %%
plt.figure(figsize=(20,15))
x = np.linspace(-25, 25, 250)
y = np.linspace(-25, 15, 250)
plt.xlim(-25, 25)
plt.ylim(-15,15)
X, Y = np.meshgrid(x, y)
Z = -Y-8*np.arctan2(Y,(X+8))+2*np.arctan2(Y-1,(X-1))+2*np.arctan2(Y+1,(X-1))+2*np.arctan2(Y-1,(X-10))+2*np.arctan2(Y+1,(X-10))
contours=plt.contour(X, Y, Z, levels=np.linspace(-25,25,30), colors='black')
plt.gca().tick_params(labelsize=25)
#plt.clabel(contours, inline=True, fontsize=15)
plt.savefig('3sspairB.png')

# %%
plt.figure(figsize=(20,15))
x = np.linspace(-25, 25, 250)
y = np.linspace(-25, 15, 250)
plt.xlim(-25, 25)
plt.ylim(-15,15)
X, Y = np.meshgrid(x, y)
Z = -Y-8*np.arctan2(Y,(X+8))+4*np.arctan2(Y,(X-1))+4*np.arctan2(Y,(X-10))
contours=plt.contour(X, Y, Z, levels=np.linspace(-25,25,30), colors='black')
plt.gca().tick_params(labelsize=25)
#plt.clabel(contours, inline=True, fontsize=15)
plt.savefig('3sspairC.png')
